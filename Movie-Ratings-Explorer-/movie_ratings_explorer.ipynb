# %% [markdown]
# # Movie Ratings Explorer

# %% [markdown]
# ###### Author: Visura Rodrigo | Dataset: IMDb Top 1000 Movies (imdb_top_1000.csv)

# %% [markdown]
# ##### --- STEP 0: Install and Load Required Libraries ---

# %%
# !pip install ipython-sql --quiet
# !pip install prettytable==2.0.0 --quiet
# !pip install matplotlib seaborn pandas --quiet

# %%
# Load the SQL extension
# %load_ext sql

# %% [markdown]
# #### --- STEP 1: Load Dataset and Create SQLite Database ---

# %%
# Import necessary libraries
import pandas as pd
import sqlite3
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load CSV into pandas DataFrame
df = pd.read_csv('imdb_top_1000.csv')
print("CSV Loaded - Sample Data:")
display(df.head())
# Out:
# CSV Loaded - Sample Data:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
#                                             Overview  Meta_score  \
# 0  Two imprisoned men bond over a number of years...        80.0
# 1  An organized crime dynasty's aging patriarch t...       100.0
# 2  When the menace known as the Joker wreaks havo...        84.0
# 3  The early life and career of Vito Corleone in ...        90.0
# 4  A jury holdout attempts to prevent a miscarria...        96.0
#
#                Director           Star1           Star2          Star3  \
# 0        Frank Darabont     Tim Robbins  Morgan Freeman     Bob Gunton
# 1  Francis Ford Coppola   Marlon Brando       Al Pacino     James Caan
# 2     Christopher Nolan  Christian Bale    Heath Ledger  Aaron Eckhart
# 3  Francis Ford Coppola       Al Pacino  Robert De Niro  Robert Duvall
# 4          Sidney Lumet     Henry Fonda     Lee J. Cobb  Martin Balsam
#
#             Star4  No_of_Votes        Gross
# 0  William Sadler      2343110   28,341,469
# 1    Diane Keaton      1620367  134,966,411
# 2   Michael Caine      2303232  534,858,444
# 3    Diane Keaton      1129952   57,300,000
# 4    John Fiedler       689845    4,360,000

# %%
# Connect to SQLite Database (creates if doesn't exist)
conn = sqlite3.connect('movies.db')

# %%
# Create the Movies table (replace if exists)
create_table_query = '''
CREATE TABLE IF NOT EXISTS Movies (
    Series_Title TEXT,
    Released_Year INTEGER,
    Genre TEXT,
    Director TEXT,
    IMDB_Rating REAL,
    No_of_Votes INTEGER,
    Gross REAL,
    Meta_score REAL
);
'''
conn.execute("DROP TABLE IF EXISTS Movies;")  # Clean previous if any
conn.execute(create_table_query)
conn.commit()

# %%
# Select only the columns that match the Movies table schema
columns_to_use = ['Series_Title', 'Released_Year', 'Genre', 'Director', 'IMDB_Rating', 'No_of_Votes', 'Gross', 'Meta_score']
df[columns_to_use].to_sql('Movies', conn, if_exists='append', index=False)
print("Data imported into SQLite database.")
# Out:
# Data imported into SQLite database.

# %%
# Close connection for now 
conn.close()

# %% [markdown]
# #### --- STEP 2: Connect to Database from SQL Magic ---

# %%
# Set PrettyTable style to avoid error
# %config SqlMagic.style = 'PLAIN_COLUMNS'

# %%
# Connect SQL magic to the SQLite database file
# %sql sqlite:///movies.db

# %% [markdown]
# #### --- STEP 3: Exploratory Analysis SQL ---

# %%
# Top 10 Highest Rated Movies
print("Top 10 Highest Rated Movies:")
# %sql SELECT Series_Title AS Title, Released_Year AS Year, IMDB_Rating AS Rating FROM Movies ORDER BY IMDB_Rating DESC LIMIT 10;
# Out:
# Top 10 Highest Rated Movies:
#  * sqlite:///movies.db
# Done.
# [('The Shawshank Redemption', 1994, 9.3),
#  ('The Godfather', 1972, 9.2),
#  ('The Dark Knight', 2008, 9.0),
#  ('The Godfather: Part II', 1974, 9.0),
#  ('12 Angry Men', 1957, 9.0),
#  ('The Lord of the Rings: The Return of the King', 2003, 8.9),
#  ('Pulp Fiction', 1994, 8.9),
#  ("Schindler's List", 1993, 8.9),
#  ('Inception', 2010, 8.8),
#  ('Fight Club', 1999, 8.8)]

# %%
# Number of Movies per Genre
print("\nCounts of Movies per Genre (top 10):")
# %sql SELECT Genre, COUNT(*) AS MovieCount FROM Movies GROUP BY Genre ORDER BY MovieCount DESC LIMIT 10;
# Out:
# Counts of Movies per Genre (top 10):
#  * sqlite:///movies.db
# Done.
# [('Drama', 85),
#  ('Drama, Romance', 37),
#  ('Comedy, Drama', 35),
#  ('Comedy, Drama, Romance', 31),
#  ('Action, Crime, Drama', 30),
#  ('Crime, Drama, Thriller', 28),
#  ('Biography, Drama, History', 28),
#  ('Crime, Drama, Mystery', 27),
#  ('Crime, Drama', 26),
#  ('Animation, Adventure, Comedy', 24)]

# %%
# Movies Released After 2010 with Rating > 8.0
print("\nHighly Rated Movies Released After 2010:")
# %sql SELECT Series_Title AS Title, Released_Year AS Year, IMDB_Rating AS Rating FROM Movies WHERE Released_Year > 2010 AND IMDB_Rating > 8.0 ORDER BY IMDB_Rating DESC LIMIT 10;
# Out:
# Highly Rated Movies Released After 2010:
#  * sqlite:///movies.db
# Done.
# [('Hamilton', 2020, 8.6),
#  ('Gisaengchung', 2019, 8.6),
#  ('Soorarai Pottru', 2020, 8.6),
#  ('Interstellar', 2014, 8.6),
#  ('Joker', 2019, 8.5),
#  ('Whiplash', 2014, 8.5),
#  ('The Intouchables', 2011, 8.5),
#  ('Capharnaüm', 2018, 8.4),
#  ('Ayla: The Daughter of War', 2017, 8.4),
#  ('Vikram Vedha', 2017, 8.4)]

# %%
# Top 10 Directors by Number of Movies
print("\nTop 10 Directors by Number of Movies:")
# %sql SELECT Director, COUNT(*) AS NumberOfMovies FROM Movies GROUP BY Director ORDER BY NumberOfMovies DESC LIMIT 10;
# Out:
# Top 10 Directors by Number of Movies:
#  * sqlite:///movies.db
# Done.
# [('Alfred Hitchcock', 14),
#  ('Steven Spielberg', 13),
#  ('Hayao Miyazaki', 11),
#  ('Martin Scorsese', 10),
#  ('Akira Kurosawa', 10),
#  ('Woody Allen', 9),
#  ('Stanley Kubrick', 9),
#  ('Billy Wilder', 9),
#  ('Quentin Tarantino', 8),
#  ('David Fincher', 8)]

# %%
#Average rating and revenue by genre 
print("\nAverage IMDb Rating and Gross Revenue by Genre:")
# %sql SELECT Genre,ROUND(AVG(IMDB_Rating),2) AS Avg_Rating,ROUND(AVG(Gross),2) AS Avg_Revenue,COUNT(*) AS Movie_Count FROM Movies WHERE Gross IS NOT NULL GROUP BY Genre ORDER BY Avg_Rating DESC;
# Out:
# Average IMDb Rating and Gross Revenue by Genre:
#  * sqlite:///movies.db
# Done.
# [('Horror, Sci-Fi', 8.4, 78.0, 1),
#  ('Crime, Mystery, Thriller', 8.4, 25.5, 2),
#  ('Action, Sci-Fi', 8.4, 137.67, 3),
#  ('Western', 8.35, 14.25, 4),
#  ('Drama, Mystery, War', 8.35, 44.5, 2),
#  ('Mystery, Romance, Thriller', 8.3, 3.0, 1),
#  ('Crime, Drama, Sci-Fi', 8.3, 6.0, 1),
#  ('Crime, Drama, Music', 8.3, 1.0, 1),
#  ('Comedy, Musical, Romance', 8.3, 8.0, 1),
#  ('Adventure, Mystery, Thriller', 8.3, 13.0, 1),
#  ('Drama, Family, Sport', 8.25, 467.0, 2),
#  ('Crime, Drama, Fantasy', 8.25, 69.0, 2),
#  ('Action, Adventure, Drama', 8.22, 244.25, 12),
#  ('Drama, Fantasy, War', 8.2, 37.0, 1),
#  ('Drama, Family', 8.2, 66.5, 2),
#  ('Comedy, Music, Romance', 8.2, 25.0, 1),
#  ('Adventure, Drama, War', 8.2, 82.0, 2),
#  ('Action, Drama, Sport', 8.2, 13.0, 1),
#  ('Action, Comedy, Romance', 8.2, 977.0, 1),
#  ('Action, Adventure, Fantasy', 8.2, 352.33, 6),
#  ('Action, Adventure', 8.18, 229.2, 5),
#  ('Adventure, Drama, Sci-Fi', 8.17, 150.33, 3),
#  ('Action, Drama, War', 8.17, 3.0, 3),
#  ('Crime, Drama', 8.16, 79.46, 24),
#  ('Drama, Romance, Sci-Fi', 8.15, 29.5, 2),
#  ('Adventure, Sci-Fi', 8.15, 44.5, 2),
#  ('Adventure, Comedy, Sci-Fi', 8.15, 164.0, 2),
#  ('Action, Drama, Sci-Fi', 8.15, 148.0, 2),
#  ('Comedy, Drama, Thriller', 8.13, 20.67, 3),
#  ('Mystery, Thriller', 8.12, 32.83, 6),
#  ('Horror, Mystery, Sci-Fi', 8.1, 13.0, 1),
#  ('Film-Noir, Mystery, Thriller', 8.1, 449.0, 1),
#  ('Drama, History, Romance', 8.1, 100.0, 2),
#  ('Crime, Drama, Film-Noir', 8.1, 220.33, 3),
#  ('Comedy, Crime, Sport', 8.1, 17.0, 1),
#  ('Comedy, Crime, Romance', 8.1, 348.0, 1),
#  ('Animation, Adventure, Fantasy', 8.1, 495.0, 1),
#  ('Adventure, Drama, Western', 8.1, 94.5, 2),
#  ('Adventure, Drama, Musical', 8.1, 70.0, 1),
#  ('Drama, Western', 8.07, 144.67, 3),
#  ('Drama, War', 8.07, 85.91, 11),
#  ('Comedy, Drama, War', 8.07, 202.25, 4),
#  ('Animation, Adventure, Drama', 8.07, 320.25, 4),
#  ('Drama, Music', 8.05, 9.5, 4),
#  ('Drama, Horror', 8.05, 48.0, 2),
#  ('Comedy, Romance', 8.05, 61.25, 4),
#  ('Comedy, Drama, Musical', 8.05, 5.5, 2),
#  ('Drama, Romance, War', 8.03, 41.25, 4),
#  ('Drama, Mystery, Sci-Fi', 8.03, 106.75, 4),
#  ('Drama, Mystery', 8.03, 36.0, 3),
#  ('Film-Noir, Mystery', 8.0, 2.0, 1),
#  ('Drama, Thriller, War', 8.0, 81.5, 2),
#  ('Drama, History', 8.0, 55.0, 1),
#  ('Drama, Film-Noir, Mystery', 8.0, 4.0, 1),
#  ('Drama, Film-Noir', 8.0, 6.0, 2),
#  ('Crime, Drama, Musical', 8.0, 4.0, 1),
#  ('Comedy, Drama, Family', 8.0, 38.33, 6),
#  ('Animation, Crime, Mystery', 8.0, 776.0, 1),
#  ('Animation, Adventure, Family', 8.0, 176.5, 8),
#  ('Animation, Action, Sci-Fi', 8.0, 553.0, 1),
#  ('Adventure, Thriller', 8.0, 260.0, 1),
#  ('Adventure, Drama, Thriller', 8.0, 25.0, 3),
#  ('Adventure, Drama', 8.0, 72.5, 2),
#  ('Action, Sci-Fi, Thriller', 8.0, 73.5, 2),
#  ('Action, Drama, Western', 8.0, 13.0, 2),
#  ('Action, Crime, Comedy', 8.0, 3.0, 1),
#  ('Biography, Drama, History', 7.99, 60.13, 23),
#  ('Drama, Sci-Fi', 7.98, 95.2, 5),
#  ('Adventure, Biography, Drama', 7.98, 25.8, 5),
#  ('Drama', 7.97, 125.71, 75),
#  ('Crime, Thriller', 7.97, 89.67, 3),
#  ('Biography, Drama', 7.97, 69.36, 11),
#  ('Animation, Drama, Fantasy', 7.97, 296.0, 3),
#  ('Adventure, Drama, History', 7.97, 86.33, 3),
#  ('Drama, Mystery, Thriller', 7.96, 68.13, 8),
#  ('Animation, Action, Adventure', 7.96, 200.5, 10),
#  ('Drama, Mystery, Romance', 7.95, 13.17, 6),
#  ('Drama, Fantasy, Music', 7.95, 11.5, 2),
#  ('Biography, Crime, Drama', 7.95, 62.0, 15),
#  ('Action, Drama, Mystery', 7.95, 238.5, 4),
#  ('Crime, Drama, Thriller', 7.94, 54.24, 25),
#  ('Crime, Drama, Mystery', 7.94, 109.71, 24),
#  ('Comedy, Crime, Drama', 7.94, 163.21, 14),
#  ('Drama, Romance', 7.93, 95.13, 31),
#  ('Biography, Comedy, Drama', 7.93, 38.5, 6),
#  ('Action, Biography, Drama', 7.93, 42.17, 6),
#  ('Action, Adventure, Sci-Fi', 7.93, 280.38, 21),
#  ('Animation, Adventure, Comedy', 7.92, 231.15, 20),
#  ('Drama, Music, Romance', 7.91, 96.86, 7),
#  ('Horror', 7.9, 117.0, 2),
#  ('Drama, Thriller, Western', 7.9, 9.0, 1),
#  ('Drama, Sport', 7.9, 60.17, 6),
#  ('Drama, Music, Mystery', 7.9, 1.0, 1),
#  ('Drama, Film-Noir, Romance', 7.9, 10.0, 1),
#  ('Crime, Film-Noir, Thriller', 7.9, 7.0, 1),
#  ('Crime, Film-Noir, Mystery', 7.9, 6.0, 1),
#  ('Comedy, Mystery, Romance', 7.9, 13.0, 1),
#  ('Comedy, Music', 7.9, 188.0, 1),
#  ('Biography, Drama, War', 7.9, 61.0, 1),
#  ('Animation, Family, Fantasy', 7.9, 96.2, 5),
#  ('Animation, Biography, Drama', 7.9, 4.5, 2),
#  ('Animation, Action, Crime', 7.9, 173.67, 3),
#  ('Adventure, Horror, Sci-Fi', 7.9, 10.0, 1),
#  ('Adventure, Drama, Fantasy', 7.9, 105.83, 6),
#  ('Adventure, Comedy, Fantasy', 7.9, 38.0, 2),
#  ('Adventure, Comedy, Crime', 7.9, 52.0, 2),
#  ('Action, Comedy, Crime', 7.9, 25.5, 2),
#  ('Action, Biography, Crime', 7.9, 41.0, 2),
#  ('Action, Adventure, Romance', 7.9, 3.0, 1),
#  ('Action, Adventure, Horror', 7.9, 5.0, 1),
#  ('Action, Adventure, History', 7.9, 53.0, 1),
#  ('Comedy, Drama, Romance', 7.89, 98.85, 26),
#  ('Drama, Thriller', 7.88, 52.33, 9),
#  ('Drama, Fantasy, Romance', 7.88, 47.25, 4),
#  ('Crime, Drama, Romance', 7.88, 125.0, 4),
#  ('Action, Drama', 7.88, 86.75, 4),
#  ('Action, Adventure, Comedy', 7.88, 213.11, 9),
#  ('Drama, History, Thriller', 7.87, 64.0, 3),
#  ('Drama, Family, Musical', 7.87, 51.33, 3),
#  ('Comedy, Drama, Music', 7.87, 52.33, 3),
#  ('Comedy, Drama, Fantasy', 7.87, 320.0, 3),
#  ('Adventure, Comedy, Drama', 7.87, 11.86, 7),
#  ('Action, Thriller', 7.87, 77.33, 3),
#  ('Action, Mystery, Thriller', 7.87, 174.67, 3),
#  ('Comedy, Drama', 7.86, 62.83, 29),
#  ('Biography, Drama, Music', 7.86, 194.0, 7),
#  ('Horror, Mystery, Thriller', 7.85, 90.0, 4),
#  ('Drama, Romance, Thriller', 7.85, 12.5, 2),
#  ('Action, Crime, Drama', 7.85, 118.68, 22),
#  ('Biography, Drama, Thriller', 7.83, 85.0, 3),
#  ('Comedy', 7.82, 83.69, 13),
#  ('Biography, Drama, Sport', 7.82, 68.67, 9),
#  ('Thriller', 7.8, 17.0, 1),
#  ('Mystery, Sci-Fi, Thriller', 7.8, 35.5, 2),
#  ('Horror, Thriller', 7.8, 68.0, 2),
#  ('Family, Sci-Fi', 7.8, 435.0, 1),
#  ('Family, Fantasy, Musical', 7.8, 4.0, 1),
#  ('Drama, Music, Musical', 7.8, 354.67, 3),
#  ('Drama, Horror, Thriller', 7.8, 30.0, 3),
#  ('Drama, History, Mystery', 7.8, 2.0, 1),
#  ('Crime, Drama, History', 7.8, 34.0, 1),
#  ('Comedy, Horror', 7.8, 8.0, 2),
#  ('Comedy, Fantasy, Romance', 7.8, 45.33, 3),
#  ('Comedy, Family, Fantasy', 7.8, 102.0, 1),
#  ('Biography, Drama, Family', 7.8, 82.0, 3),
#  ('Animation, Sci-Fi', 7.8, 193.0, 1),
#  ('Animation, Comedy, Drama', 7.8, 7.0, 1),
#  ('Animation, Biography, Crime', 7.8, 6.0, 1),
#  ('Adventure, Fantasy', 7.8, 280.5, 2),
#  ('Adventure, Biography, Crime', 7.8, 107.0, 1),
#  ('Action, Comedy, Mystery', 7.8, 23.0, 1),
#  ('Action, Adventure, Western', 7.8, 8.0, 2),
#  ('Adventure, Family, Fantasy', 7.79, 174.43, 7),
#  ('Comedy, Crime', 7.78, 40.25, 4),
#  ('Action, Crime, Thriller', 7.78, 35.83, 6),
#  ('Action, Drama, History', 7.77, 83.0, 3),
#  ('Action, Comedy, Fantasy', 7.77, 86.67, 3),
#  ('Comedy, Music, Musical', 7.75, 7.5, 2),
#  ('Comedy, Family', 7.75, 152.5, 2),
#  ('Adventure, Drama, Romance', 7.75, 384.5, 2),
#  ('Action, Adventure, Thriller', 7.74, 168.4, 5),
#  ('Adventure, Comedy, Family', 7.73, 59.0, 3),
#  ('Drama, History, War', 7.72, 150.75, 4),
#  ('Drama, Sci-Fi, Thriller', 7.7, 92.0, 4),
#  ('Drama, Horror, Sci-Fi', 7.7, 24.5, 2),
#  ('Drama, Horror, Mystery', 7.7, 11.0, 1),
#  ('Drama, History, Music', 7.7, 1.0, 1),
#  ('Drama, Family, Fantasy', 7.7, 10.0, 1),
#  ('Comedy, Western', 7.7, 119.0, 1),
#  ('Biography, Drama, Romance', 7.7, 35.0, 1),
#  ('Animation, Drama, Family', 7.7, 420.0, 2),
#  ('Animation, Comedy, Fantasy', 7.7, 52.0, 1),
#  ('Animation, Action, Fantasy', 7.7, 151.0, 1),
#  ('Action, Adventure, War', 7.7, 45.0, 1),
#  ('Drama, War, Western', 7.6, 696.0, 1),
#  ('Drama, Fantasy, Mystery', 7.6, 39.0, 1),
#  ('Animation, Drama, Romance', 7.6, 453.0, 1),
#  ('Animation, Comedy, Crime', 7.6, 251.0, 1),
#  ('Adventure, Comedy, War', 7.6, 1.0, 1),
#  ('Action, Crime, Mystery', 7.6, 132.0, 1),
#  ('Action, Adventure, Mystery', 7.6, 209.0, 1),
#  ('Action, Adventure, Family', 7.6, 301.0, 1)]

# %%
#Directors with highest average movie rating (min 5 movies)
print("\nDirectors with Highest Average Movie Rating (Minimum 5 Movies):")
# %sql SELECT Director, ROUND(AVG(IMDB_Rating), 2) AS Avg_Rating, COUNT(*) AS Movie_Count FROM Movies GROUP BY Director HAVING Movie_Count >= 5 ORDER BY Avg_Rating DESC LIMIT 10;
# Out:
# Directors with Highest Average Movie Rating (Minimum 5 Movies):
#  * sqlite:///movies.db
# Done.
# [('Christopher Nolan', 8.46, 8),
#  ('Peter Jackson', 8.4, 5),
#  ('Francis Ford Coppola', 8.4, 5),
#  ('Charles Chaplin', 8.33, 6),
#  ('Sergio Leone', 8.27, 6),
#  ('Stanley Kubrick', 8.23, 9),
#  ('Akira Kurosawa', 8.22, 10),
#  ('Quentin Tarantino', 8.18, 8),
#  ('Martin Scorsese', 8.17, 10),
#  ('Ingmar Bergman', 8.14, 7)]

# %% [markdown]
# #### --- STEP 4: Python Data Analysis & Visualization ---

# %%
# Read top genres data to visualize
genre_df = pd.read_sql_query('''
SELECT Genre, COUNT(*) AS MovieCount
FROM Movies
GROUP BY Genre
ORDER BY MovieCount DESC
LIMIT 10;
''', conn)

# Bar plot for movie counts by genre
plt.figure(figsize=(10,6))
sns.barplot(
    data=genre_df,
    x='Genre',
    y='MovieCount',
    palette=sns.color_palette('husl', n_colors=len(genre_df))
)
plt.title('Top 10 Movie Genres by Count')
plt.xlabel('Genre')
plt.ylabel('Number of Movies')
plt.xticks(rotation=75)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\a12u\AppData\Local\Temp\ipykernel_28008\1307119191.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
plt.figure(figsize=(10, 6))
sns.histplot(
    df['IMDB_Rating'],
    bins=20,
    kde=True,
    color='skyblue',
    edgecolor='black',
    alpha=0.85,
)
plt.title('Distribution of IMDb Ratings', fontsize=18, fontweight='bold')
plt.xlabel('IMDb Rating', fontsize=14)
plt.ylabel('Number of Movies', fontsize=14)
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
sns.despine()
plt.tight_layout()
plt.show()

# %%
# Average IMDb Rating by Release Year (last 50 years)
avg_rating_year_df = pd.read_sql_query('''
SELECT Released_Year, AVG(IMDB_Rating) AS AvgRating
FROM Movies
WHERE Released_Year >= 1970
GROUP BY Released_Year
ORDER BY Released_Year;
''', conn)

# Filter out non-numeric years (e.g., "PG")
avg_rating_year_df_clean = avg_rating_year_df[avg_rating_year_df['Released_Year'].apply(lambda x: str(x).isdigit())].copy()
avg_rating_year_df_clean['Released_Year'] = avg_rating_year_df_clean['Released_Year'].astype(int)

plt.figure(figsize=(12,6))
sns.lineplot(data=avg_rating_year_df_clean, x='Released_Year', y='AvgRating', marker='o')
plt.title('Average IMDb Rating by Release Year (Since 1970)')
plt.xlabel('Year')
plt.ylabel('Average IMDb Rating')
plt.grid(True)
plt.show()
