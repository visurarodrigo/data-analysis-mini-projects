# %% [markdown]
# # Netflix Media Consumption Analysis: Data Loading and Preparation
#
# This notebook loads the raw Netflix dataset, applies cleaning and feature engineering steps, and performs foundational dataset inspection before deeper analysis.
#
# ## Goals
# - Load source data from the project `data/raw` folder.
# - Apply standardized preprocessing functions from `src/preprocess.py`.
# - Validate dataset structure, completeness, and summary statistics.

# %% [markdown]
# ## 1. Environment Setup
#
# Import dependencies and configure project-relative paths for portability.

# %%
from pathlib import Path
import os
import sys

# Add project root to Python path
sys.path.append(os.path.abspath(".."))

from src.preprocess import clean_data, feature_engineering, load_data

# %% [markdown]
# ## 2. Load Raw Dataset
#
# Load the raw Netflix titles file using a project-relative path.

# %%
data_path = Path("../data/raw/netflix_titles.csv")
df = load_data(data_path)

print(f"Loaded dataset from: {data_path}")
print(f"Rows: {df.shape[0]:,} | Columns: {df.shape[1]}")
# Out:
# Loaded dataset from: ..\data\raw\netflix_titles.csv
# Rows: 8,807 | Columns: 12

# %% [markdown]
# ## 3. Clean and Engineer Features
#
# Apply preprocessing steps and create analysis-ready fields such as year/month added and primary genre.

# %%
df = clean_data(df)
print("Data cleaning completed.")
# Out:
# Data cleaning completed.

# %%
df = feature_engineering(df)

engineered_columns = [
    "year_added",
    "month_added",
    "duration_minutes",
    "duration_type",
    "primary_genre",
]
print("Feature engineering completed.")
print("New columns present:", [c for c in engineered_columns if c in df.columns])
# Out:
# Feature engineering completed.
# New columns present: ['year_added', 'month_added', 'duration_minutes', 'duration_type', 'primary_genre']

# %% [markdown]
# ## 4. Exploratory Snapshot
#
# Run baseline checks to understand structure, quality, and distribution characteristics.

# %%
print(f"Shape: {df.shape}")
print(f"Duplicate rows: {df.duplicated().sum()}")

missing_summary = df.isna().sum().sort_values(ascending=False)
missing_summary[missing_summary > 0].head(10)
# Out:
# Shape: (8807, 17)
# Duplicate rows: 0
# month_added         98
# year_added          98
# date_added          98
# duration_minutes     3
# dtype: int64

# %%
# Preview first rows
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water          Unknown
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans          Unknown
# 4      s5  TV Show           Kota Factory          Unknown
#
#                                                 cast        country  \
# 0                                            Unknown  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...        Unknown
# 3                                            Unknown        Unknown
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   date_added  release_year rating   duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
# 2 2021-09-24          2021  TV-MA   1 Season
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   show_id           8807 non-null   object
#  1   type              8807 non-null   object
#  2   title             8807 non-null   object
#  3   director          8807 non-null   object
#  4   cast              8807 non-null   object
#  5   country           8807 non-null   object
#  6   date_added        8709 non-null   datetime64[ns]
#  7   release_year      8807 non-null   int64
#  8   rating            8807 non-null   object
#  9   duration          8807 non-null   object
#  10  listed_in         8807 non-null   object
#  11  description       8807 non-null   object
#  12  year_added        8709 non-null   float64
#  13  month_added       8709 non-null   float64
#  14  duration_minutes  8804 non-null   float64
#  15  duration_type     8807 non-null   object
# ...

# %%
df.describe(include="all").T
# Out:
#                    count unique  \
# show_id             8807   8807
# type                8807      2
# title               8807   8807
# director            8807   4529
# cast                8807   7693
# country             8807    749
# date_added          8709    NaN
# release_year      8807.0    NaN
# rating              8807     18
# duration            8807    221
# listed_in           8807    514
# description         8807   8775
# year_added        8709.0    NaN
# month_added       8709.0    NaN
# duration_minutes  8804.0    NaN
# duration_type       8807      4
# primary_genre       8807     36
#
#                                                                 top  freq  \
# show_id                                                          s1     1
# type                                                          Movie  6131
# title                                          Dick Johnson Is Dead     1
# director                                                    Unknown  2634
# ...
